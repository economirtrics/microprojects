# %% [markdown]
# <h1 style="text-align: center">
# <div style="color: #DD3403; font-size: 60%">Data Science DISCOVERY MicroProject</div>
# <span style="">MicroProject #7: Creating an Image Mosaic (Part #2)</span>
# <div style="font-size: 60%;"><a href="https://discovery.cs.illinois.edu/microproject/creating-an-image-mosaic/">https://discovery.cs.illinois.edu/microproject/creating-an-image-mosaic/</a></div>
# </h1>
#
# <hr style="color: #DD3403;">

# %% [markdown]
# ⚠️ You must <b>FULLY COMPLETE</b> `07-creating-an-image-mosaic.ipynb` before starting on this notebook.
# - Make sure your first notebook is completed and saved.
# - This notebook imports your previous work to run.
#
# Run this cell to import your previous work:

# %%
# Run this cell to import your previous work:
# %run ./07-creating-an-image-mosaic.ipynb
# Out:
# ✅ `green_pixel` contains just one pixel!
# ✅ `green_pixel` is a green pixel!
# 🎉 All tests passed! 🎉
# ✅ `r_median` is a number!
# ✅ `r_median` has the correct value!
# ✅ `g_median` is a number!
# ✅ `g_median` has the correct value!
# ✅ `b_median` is a number!
# ✅ `b_median` has the correct value!
# 🎉 All tests passed! 🎉
# ✅ Dictionary contain the key `r_avg`.
# ✅ Dictionary contain the key `g_avg`.
# ✅ Dictionary contain the key `b_avg`.
# ✅ The values all appear correct!
# 🎉 All tests passed! 🎉
# ✅ Test case for findImageSubset(image, x0=0, y0=0, width=2, height=2) appears correct.
# ✅ Test case for findImageSubset(image, x0=2, y0=0, width=2, height=2) appears correct.
# ✅ Test case for findImageSubset(image, x0=2, y0=2, width=2, height=2) appears correct.
# ✅ Test case for findImageSubset(image, x0=5, y0=1, width=2, height=2) appears correct.
# ✅ Test case for findImageSubset(image, x0=5, y0=1, width=3, height=2) appears correct.
# ✅ Test case for findImageSubset(image, x0=5, y0=1, width=4, height=3) appears correct.
# ✅ Test case for findImageSubset(image, x0=1, y0=1, width=1, height=3) appears correct.
# 🎉 All tests passed! 🎉
# ✅ Test case for findAverageImageSubsetColor(image, x=0, y=0, width=2, height=2) appears correct.
# ✅ Test case for findAverageImageSubsetColor(image, x=2, y=0, width=2, height=2) appears correct.
# ✅ Test case for findAverageImageSubsetColor(image, x=2, y=2, width=2, height=2) appears correct.
# ✅ Test case for findAverageImageSubsetColor(image, x=5, y=1, width=2, height=2) appears correct.
# ✅ Test case for findAverageImageSubsetColor(image, x=5, y=1, width=3, height=2) appears correct.
# ✅ Test case for findAverageImageSubsetColor(image, x=5, y=1, width=4, height=3) appears correct.
# ✅ Test case for findAverageImageSubsetColor(image, x=1, y=1, width=1, height=3) appears correct.
# 🎉 All tests passed! 🎉
# ⚠️ Your file ./base.jpg is large! ⚠️
# - If this is being used as a tile image, your mosaic may run for a LONG time due to the size of your photo.
# - View the notebook `shrink-images.ipynb` to pre-shrink the images into a new `tiles-small` folder if you need to speed up your program.
# ✅ Test case #1 (r=0, g=0, b=0) passed!
# ✅ Test case #1 (r=47, g=49, b=38) passed!
# ✅ Test case #1 (r=54, g=49, b=38) passed!
# ✅ Test case #1 (r=54, g=49, b=52) passed!
# ✅ Test case #1 (r=-100, g=-100, b=-100) passed!
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Section 9: Selecting Your Base Image
#
# The first you will do is find your **base image** for your mosaic.  Mosaics work the best when the image has lots of different regions of color *(photos usually work really well while cell-shaded animations usually don't work as well since there are large large regions of the identical color)*.
#
# Find an image that you want to use as your **base image**.
# - Copy the base image into the same directory (folder) as this Python notebook.
# - Make sure you know the name of the file (you may want to rename it to something like `base.jpg`).
#
# Write the filename of your base image below:

# %%
# What is the file name of your base image?
baseImageFileName = "base.jpg"
baseImageFileName
# Out:
# 'base.jpg'

# %%
### Test Case to Verify Your Base Image
import os
assert( os.path.exists(baseImageFileName) ), f"Your `baseImageFileName` is not valid: the file {baseImageFileName} was not found."
print("\u2705 Your `baseImageFileName` file exists!")
# Out:
# ✅ Your `baseImageFileName` file exists!

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Section 10: Selecting Your Tile Images
#
# Now it's time to collect your tile images!
#
# **Create a new folder** with the name `tiles` and add the tile images that you want to use as your tile images.  (The more images the better, and you can add to these images at any time.)
# - Tile images can be ANY images you have -- it's the most fun when you use images that have a common theme,
# - You can use your images from your own camera roll,
# - You can you a images you save from a web image search, or
# - You can use the UIUC instagram images that we provide on the MicroProject overview page.
#
# In general, you want **at least 100 tile images to get a good mosaic** since you will be replacing each region of your base image with one of your tile images.  The absolutely minimum is 30 images.  The more tile images you have, the better the match can be for each tile image and the better your mosaic will look.
#
# Write the name of the the tiles image folder you want to use below:

# %%
# What folder contains your tile images?
# - You can change this so you can have multiple different folders of tile images.
tileImageFolder = "tiles"
tileImageFolder
# Out:
# 'tiles'

# %%
### Test Case to Verify Your Tile Images
import os

assert( os.path.exists(tileImageFolder) ), f"Your `tileImageFolder` is not valid: the path '{tileImageFolder}' was not found."
assert( os.path.isdir(tileImageFolder) ), f"Your `tileImageFolder` is not valid: the path '{tileImageFolder}' is not a directory."
assert( len(DISCOVERY.listTileImagesInPath(tileImageFolder)) >= 30 ), f"Your only have {DISCOVERY.listTileImagesInPath(tileImageFolder)} files in your {tileImageFolder} folder.  You need at least 30 image files."
print("\u2705 Your `baseImageFileName` file exists!")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[42], line 6
#       4 assert( os.path.exists(tileImageFolder) ), f"Your `tileImageFolder` is not valid: the path '{tileImageFolder}' was not found."
#       5 assert( os.path.isdir(tileImageFolder) ), f"Your `tileImageFolder` is not valid: the path '{tileImageFolder}' is not a directory."
# ----> 6 assert( len(DISCOVERY.listTileImagesInPath(tileImageFolder)) >= 30 ), f"Your only have {DISCOVERY.listTileImagesInPath(tileImageFolder)} files in your {tileImageFolder} folder.  You need at least 30 image files."
#       7 print("\u2705 Your `baseImageFileName` file exists!")
#
# AssertionError: Your only have ['tiles/sample.png'] files in your tiles folder.  You need at least 30 image files.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Section 11: Create Your Mosaic!
#
# There are two major variables the impact your mosaic.  We've provided reasonable default values (`200` and `32`), but you can update these values to adjust your mosaic:

# %%
# What is the maximum number of tiles should your mosaic use across?
# - More tiles across will increase the quality of the final image.
# - More tiles across will cause your program to run slower.
# ...if you have bugs, start this value slow (it won't look great, but it will make it run fast!)
# ...a value around 200 usually looks quite good, but play around with this number!
maximumTilesX = 200

# What height should your tiles be in your mosaic?
# - A larger tile image will result in a larger output file.
# - A larger tile image will result in your program running slower.
# - A larger tile image will result in more detail in the output file.
tileHeight = 32

# %% [markdown]
# ### It's Mosaic Time! 🎉
#
# Run the code to create your mosaic.
#
# - This **WILL SERIOUSLY** take a bit of time (even more time on slower/older laptops).
# - This will **run fastest if your laptop is plugged in** (when it's unplugged, your laptop will try and save power and may not run at full speed).

# %% [markdown]
# ### Section 11.1: Generate the `df_tiles` DataFrame from your tile images
#
# ⚠️: If you are using **large images** (ex: phone camera images, etc), this **may take many hours to run**.  You may want to shrink them using the notebook we provided:
# - We have provided you a notebook `shrink-images.ipynb` that will shrink your tile images to a small size to run faster.
# - *(In DISCOVERY, we focus on understanding the algorithm and not using the most efficient data structures; there are more efficient ways to do this.)*.

# %%
print(f"Creating `df_tiles` from tile images in folder `{tileImageFolder}`...")
df_tiles = createTilesDataFrame(tileImageFolder)
print(f"...found {len(df_tiles)} tile images!")
df_tiles
# Out:
# Creating `df_tiles` from tile images in folder `tiles`...
# ...found 1 tile images!
#            fileName           r           g           b
# 0  tiles/sample.png  143.777778  127.333333  126.777778

# %% [markdown]
# ### Section 11.2: Loading your `baseImage`
#
# ⚠️: If you are using **an extremely large image** this may take awhile to run (particularly on older laptops or if you're not plugged in).  You may want to resize your baseImage if this is taking a long time to run.  An image ~1000px across may take anywhere from 10 seconds to 5 minutes.

# %%
print(f"Loading your base image `{baseImageFileName}`...")
baseImage = DISCOVERY.loadImageAsDataFrame(baseImageFileName)
width = baseImage.x.max()
height = baseImage.y.max()
baseImage
# Out:
# Loading your base image `base.jpg`...
#           x    y    r    g    b
# 0         0    0   44   15    1
# 1         0    1   43   14    0
# 2         0    2   41   13    1
# 3         0    3   40   12    0
# 4         0    4   38   11    0
# ...     ...  ...  ...  ...  ...
# 409595  639  635  199  183  158
# 409596  639  636  198  182  157
# 409597  639  637  209  193  168
# 409598  639  638  215  199  174
# 409599  639  639  211  195  170
#
# [409600 rows x 5 columns]

# %% [markdown]
# ### Section 11.3: Create a mosaic by finding the best match
#
# ⚠️: If you are using a large values for `maximumTilesX` (set at the beginning of this section), this may take a long time.

# %%
import sys

# Find the pixelsPerTile to know the pixels used in the base image per mosaic tile:
import math

pixelsPerTile = int(math.ceil(width / maximumTilesX))
width = int(math.floor(width / pixelsPerTile) * pixelsPerTile)
height = int(math.floor(height / pixelsPerTile) * pixelsPerTile)
tilesX = int(width / pixelsPerTile)
tilesY = int(height / pixelsPerTile)

print(f"Your base image size is {width}px by {height}px.")
print(f"- Based on your setting of `maximumTilesX = {maximumTilesX}`, we can evenly fit {tilesX} tiles in each row.")
print(f"  (Each tile will use a {pixelsPerTile}px by {pixelsPerTile}px square of pixels from your base image.)")
print(f"- To maintain the aspect ratio of your base image, there will be {tilesY} total rows of tiles.")
print(f"- Total number of tiles: {tilesX} * {tilesY} = {tilesX * tilesY} total tiles in your mosaic.")
print()
print(f"Finding best replacement image for each tile:")

# Create the mosaic:
from PIL import Image
mosaic = Image.new('RGB', (int(tilesX * tileHeight), int(tilesY * tileHeight)))
for x in range(0, width, pixelsPerTile):
  for y in range(0, height, pixelsPerTile):
    avg_color = findAverageImageSubsetColor(baseImage, x, y, pixelsPerTile, pixelsPerTile)
    replacement = findBestTile(df_tiles, avg_color["r_avg"], avg_color["g_avg"], avg_color["b_avg"])

    tile = DISCOVERY.getTileImage(replacement["fileName"].values[0], tileHeight)
    mosaic.paste(tile, (int(x / pixelsPerTile) * tileHeight, int(y / pixelsPerTile) * tileHeight))

  # Print out a progress message:
  curRow = int((x / pixelsPerTile) + 1)
  pct = (curRow / tilesX) * 100
  sys.stdout.write(f'\r  ...progress: {curRow * tilesY} / {tilesX * tilesY} ({pct:.2f}%)')

# Save it
mosaic.save('mosaic-hd.jpg')

# Save a smaller one (for posting):
import PIL
d = max(width, height)
factor = d / 4000
if factor <= 1: factor = 1

small_w = width / factor
small_h = height / factor    
baseImage = mosaic.resize( (int(small_w), int(small_h)), resample=PIL.Image.LANCZOS )
baseImage.save('mosaic-web.jpg')

# Print a message:
tada = "\N{PARTY POPPER}"
print("")
print("")
print(f"{tada} MOSAIC COMPLETE! {tada}")
print("- See `mosaic-hq.jpg` to see your HQ mosaic! (The file may be HUGE.)")
print("- See `mosaic-web.jpg` to see a mosaic best suited for the web (still big, but not HUGE)!")
# Out:
# Your base image size is 636px by 636px.
# - Based on your setting of `maximumTilesX = 200`, we can evenly fit 159 tiles in each row.
#   (Each tile will use a 4px by 4px square of pixels from your base image.)
# - To maintain the aspect ratio of your base image, there will be 159 total rows of tiles.
# - Total number of tiles: 159 * 159 = 25281 total tiles in your mosaic.
#
# Finding best replacement image for each tile:
#   ...progress: 7791 / 25281 (30.82%)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 26
#      24 for y in range(0, height, pixelsPerTile):
#      25   avg_color = findAverageImageSubsetColor(baseImage, x, y, pixelsPerTile, pixelsPerTile)
# ---> 26   replacement = findBestTile(df_tiles, avg_color["r_avg"], avg_color["g_avg"], avg_color["b_avg"])
#      28   tile = DISCOVERY.getTileImage(replacement["fileName"].values[0], tileHeight)
#      29   mosaic.paste(tile, (int(x / pixelsPerTile) * tileHeight, int(y / pixelsPerTile) * tileHeight))
#
# File ~\AppData\Local\Temp\ipykernel_35404\840833906.py:7, in findBestTile(df_tiles, r_avg, g_avg, b_avg)
#       5 def findBestTile(df_tiles, r_avg, g_avg, b_avg):
#       6   df_tiles["dist"] = (df_tiles.r - r_avg)**2 + (df_tiles.g - g_avg)**2 + (df_tiles.b - b_avg)**2
# ----> 7   return df_tiles.nsmallest(1, "dist")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:7756, in DataFrame.nsmallest(self, n, columns, keep)
#    7646 def nsmallest(
#    7647     self, n: int, columns: IndexLabel, keep: NsmallestNlargestKeep = "first"
#    7648 ) -> DataFrame:
#    7649     """
#    7650     Return the first `n` rows ordered by `columns` in ascending order.
#    7651
#    (...)
#    7754     Nauru         337000  182      NR
#    7755     """
# -> 7756     return selectn.SelectNFrame(self, n=n, keep=keep, columns=columns).nsmallest()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\methods\selectn.py:61, in SelectN.nsmallest(self)
#      59 @final
#      60 def nsmallest(self):
# ---> 61     return self.compute("nsmallest")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\methods\selectn.py:218, in SelectNFrame.compute(self, method)
#     216 # Below we save and reset the index in case index contains duplicates
#     217 original_index = frame.index
# --> 218 cur_frame = frame = frame.reset_index(drop=True)
#     219 cur_n = n
#     220 indexer = Index([], dtype=np.int64)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:6417, in DataFrame.reset_index(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6415     new_obj = self
#    6416 else:
# -> 6417     new_obj = self.copy(deep=None)
#    6418 if allow_duplicates is not lib.no_default:
#    6419     allow_duplicates = validate_bool_kwarg(allow_duplicates, "allow_duplicates")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:6811, in NDFrame.copy(self, deep)
#    6662 @final
#    6663 def copy(self, deep: bool_t | None = True) -> Self:
#    6664     """
#    6665     Make a copy of this object's indices and data.
#    6666
#    (...)
#    6809     dtype: int64
#    6810     """
# -> 6811     data = self._mgr.copy(deep=deep)
#    6812     self._clear_item_cache()
#    6813     return self._constructor_from_mgr(data, axes=data.axes).__finalize__(
#    6814         self, method="copy"
#    6815     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\managers.py:604, in BaseBlockManager.copy(self, deep)
#     601         res._blklocs = self._blklocs.copy()
#     603 if deep:
# --> 604     res._consolidate_inplace()
#     605 return res
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\managers.py:1788, in BlockManager._consolidate_inplace(self)
#    1782 def _consolidate_inplace(self) -> None:
#    1783     # In general, _consolidate_inplace should only be called via
#    1784     #  DataFrame._consolidate_inplace, otherwise we will fail to invalidate
#    1785     #  the DataFrame's _item_cache. The exception is for newly-created
#    1786     #  BlockManager objects not yet attached to a DataFrame.
#    1787     if not self.is_consolidated():
# -> 1788         self.blocks = _consolidate(self.blocks)
#    1789         self._is_consolidated = True
#    1790         self._known_consolidated = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\managers.py:2269, in _consolidate(blocks)
#    2267 new_blocks: list[Block] = []
#    2268 for (_can_consolidate, dtype), group_blocks in grouper:
# -> 2269     merged_blocks, _ = _merge_blocks(
#    2270         list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    2271     )
#    2272     new_blocks = extend_blocks(merged_blocks, new_blocks)
#    2273 return tuple(new_blocks)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\managers.py:2300, in _merge_blocks(blocks, dtype, can_consolidate)
#    2297     bvals2 = cast(Sequence[NDArrayBackedExtensionArray], bvals)
#    2298     new_values = bvals2[0]._concat_same_type(bvals2, axis=0)
# -> 2300 argsort = np.argsort(new_mgr_locs)
#    2301 new_values = new_values[argsort]
#    2302 new_mgr_locs = new_mgr_locs[argsort]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\_core\fromnumeric.py:1243, in argsort(a, axis, kind, order, stable)
#    1130 @array_function_dispatch(_argsort_dispatcher)
#    1131 def argsort(a, axis=-1, kind=None, order=None, *, stable=None):
#    1132     """
#    1133     Returns the indices that would sort an array.
#    1134
#    (...)
#    1241
#    1242     """
# -> 1243     return _wrapfunc(
#    1244         a, 'argsort', axis=axis, kind=kind, order=order, stable=stable
#    1245     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\_core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Section 12: Verify Your Mosaic Looks Good!
#
# Your mosaic is uniquely yours -- generated by your code, your base image, and your tile images! 🎉
#
# If you find your mosaic does not look like your original image, there are several factors that might cause this:
#
# 1. You may not have enough tile images.  You generally need **at least 100 tile images of a large range of colors** to start to create a decent mosaic.  If you want a high quality mosaic, use more tile images.
#
# 2. You may have set too few tiles across.  The `maximumTilesX` at the beginning of Section 11 controls the size of your grid.  A value of `maximumTilesX = 100` or higher is usually needed to create a decent mosaic.
#
# 3. Your functions may be incorrect.  We provided test cases to try and catch common errors, but we may have missed something!
#
# Add more tiles, change your parameters, or double-check your code and continue to work on this until you have a mosaic you're proud of! :)

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Section 13: Sharing and Submitting your Mosaic!
#
# We would **love** for you to share your mosaic!  We have created the discord channel `#mosaic-showcase` just to show off your mosaic -- we hope you will add your `mosaic-web.jpg` there and check out others! :)
#
#
# ### MicroProject Extra Credit
#
# Regardless on if you share it on Discord, you can earn +1 EC sharing the mosaic with us!  To do that, complete the following form: [https://forms.office.com/r/sLJR8uacKj](https://forms.office.com/r/sLJR8uacKj)
#
#
# ### MicroProject Submission
#
# To earn credit for this MicroProject and earn the MicroProject card, you need to commit your MicroProject and run the GitHub Action:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and return to https://discovery.cs.illinois.edu/microproject/bechdel-test/ and complete the section **"Commit and Grade Your Notebook"**.
#
# 3. If you see a 100% grade result on your GitHub Action, you've completed this MicroProject! 🎉
